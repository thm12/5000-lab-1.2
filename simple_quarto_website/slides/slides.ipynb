# %% [markdown]
# ---
# title: "Presentation"
# author: "Tyler McCormick"
# format: revealjs
# ---
#
# ## Slide 1
#
# - note 1
# - note 2
#
# ## Slide 2
#
# - test 1
# [@dhar2013data]
#
#
# ## image 1
#
# ![](../images/photo.png)
#
#
# ## image 2
#
# ![](../images/my_image.jpeg)
#
# ##

# %%
##
#| code-fold: true
import matplotlib.pyplot as plt
import numpy as np

x=[1, 2, 3, 4]
y=[1, 2, 3, 4]

plt.plot(x,y,'o') 
plt.show()

##
